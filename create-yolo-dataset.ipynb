# %% [markdown]
# # Create yolo dataset
#
# ## Part 1: Based on xml annotations

# %%
import os, gc, sys, yaml, shutil
from pathlib import Path
from tqdm.auto import tqdm

import math
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn import model_selection

import PIL
import cv2

import xml
import xml.etree.ElementTree as ET
from xml.dom import minidom

random.seed(42)
import warnings
warnings.filterwarnings("ignore")

# %%
DATA_PATH = Path("/kaggle/input/road-sign-detection")
os.listdir(DATA_PATH)
# Out:
# ['annotations', 'images']

# %%
# !cat /kaggle/input/road-sign-detection/annotations/road4.xml

# %%
# function to get the data from XML annotation
def extract_info_from_xml(xml_file):
    root = ET.parse(xml_file).getroot()
    
    # initialize the info dict
    info_dict = {}
    info_dict['bboxes'] = []
    
    # parse the xml tree
    for elem in root:
        # get file name
        if elem.tag == "filename":
            info_dict['filename'] = elem.text
        
        # get the image size
        elif elem.tag == "size":
            image_size = []
            for subelem in elem:
                image_size.append(int(subelem.text))
                
            info_dict['image_size'] = tuple(image_size)
            
        # get details of the bounding box
        elif elem.tag == "object":
            bbox = {}
            for subelem in elem:
                if subelem.tag == "name":
                    bbox["class"] = subelem.text
                elif subelem.tag == "bndbox":
                    for subsubelem in subelem:
                        bbox[subsubelem.tag] = int(subsubelem.text)
            info_dict['bboxes'].append(bbox)
            
    return info_dict

# %%
class_name_to_id_mapping = {
    "trafficlight": 0,
    "stop": 1,
    "speedlimit": 2,
    "crosswalk": 3
}

ANNOTATION_DIR = Path("/kaggle/input/road-sign-detection/annotations")
info_dict = extract_info_from_xml(ANNOTATION_DIR/"road350.xml")
info_dict['filename'] = info_dict['filename'].replace("png", "txt")
info_dict
# Out:
# {'bboxes': [{'class': 'speedlimit',
#    'xmin': 90,
#    'ymin': 180,
#    'xmax': 173,
#    'ymax': 263}],
#  'filename': 'road350.txt',
#  'image_size': (300, 400, 3)}

# %%
PIL.Image.open("/kaggle/input/road-sign-detection/images/road0.png").size
# Out:
# (267, 400)

# %%
labels = []
for box in info_dict['bboxes']:
    label = [class_name_to_id_mapping[box['class']], box['xmin'], box['ymin'], box['xmax'], box['ymax']]
    labels.append(label)
    
labels
# Out:
# [[2, 90, 180, 173, 263]]

# %%
def create_dataset(data_path):
    LABELS = []
    IMAGE_PATHS = []
    IMAGE_DIR = data_path/'images'
    img_paths = os.listdir(IMAGE_DIR)
    ANNOTATION_DIR = data_path/'annotations'
    for i, path in enumerate(tqdm(img_paths, total=len(img_paths))):
        iPath = f"{IMAGE_DIR}/{path}"
        assert os.path.exists(iPath)
        image = PIL.Image.open(iPath)
        image_w, image_h = image.size
        name = Path(iPath).stem
        aPath = f"{ANNOTATION_DIR}/{name}.xml"
        assert os.path.exists(aPath)
        info_dict = extract_info_from_xml(aPath)
        annots = []
        for b in info_dict['bboxes']:
            b_center_x = (b["xmin"] + b["xmax"]) / 2 
            b_center_y = (b["ymin"] + b["ymax"]) / 2
            b_width    = (b["xmax"] - b["xmin"])
            b_height   = (b["ymax"] - b["ymin"])
            
            # Normalize the coordinates
            b_center_x /= image_w 
            b_center_y /= image_h 
            b_width    /= image_w 
            b_height   /= image_h 
            
            # Convert to YOLO format
            annot = [class_name_to_id_mapping[b['class']], b_center_x, b_center_y, b_width, b_height]
            annots.append(annot)
        
        # Append the image path and corresponding annotations
        IMAGE_PATHS.append(iPath)
        LABELS.append(annots)
        
    return IMAGE_PATHS, LABELS

iPath, lPath = create_dataset(DATA_PATH)
# Out:
#   0%|          | 0/877 [00:00<?, ?it/s]

# %%
# lPath

# %%
from sklearn import model_selection

# %%
train_images, val_images, train_annotations, val_annotations = model_selection.train_test_split(
    iPath, lPath, test_size=0.2, random_state=42
)

# val_images, val_annotations, test_images, test_annotations = model_selection.train_test_split(
#     val_images, val_annotations, test_size=0.5, random_state=42
# )

# %%
# !mkdir /kaggle/working/roadsigndetection
# !mkdir /kaggle/working/roadsigndetection/train
# !mkdir /kaggle/working/roadsigndetection/valid

# !mkdir /kaggle/working/roadsigndetection/train/images /kaggle/working/roadsigndetection/train/labels
# !mkdir /kaggle/working/roadsigndetection/valid/images /kaggle/working/roadsigndetection/valid/labels

# %%
def move_file_to_folder(file, destination):
    try:
        shutil.move(file, destination)
    except Exception as e:
        print(f"Error moving file {file}: {e}")
        assert False
        
def write_annotations(name, annots, annot_dest):
    with open(f'{annot_dest}/{name}.txt', 'w') as f:
        for annot in annots:
            annot_str = ' '.join(map(str, annot))
            f.write(annot_str + '\n')

def create_folders(img_paths, annot_paths, img_dest, annot_dest):
    for i in tqdm(range(len(img_paths))):
        img_path = img_paths[i]
        img = PIL.Image.open(img_path).convert("RGB")
        name = Path(img_path).stem
        img.save(f"{name}.png")
        file = f"{name}.png"
        move_file_to_folder(file, img_dest)

        annots = annot_paths[i]
        write_annotations(name, annots, annot_dest)

# %%
# with open('label.txt', 'w') as f:
#     f.write(str(lPath[14]))
    
# # [' '.join(map(str, lPath[i])) for i in [0, 5, 14]]
# a = lPath[14]
# # ''.join(map(str, a)) if len(a) == 1 else ' '.join(map(str, a))
# str(a[0]) if len(a) == 1 else ', '.join(map(str, a))

# %%
create_folders(img_paths=train_images, 
               annot_paths=train_annotations,
               img_dest="/kaggle/working/roadsigndetection/train/images",
               annot_dest="/kaggle/working/roadsigndetection/train/labels"
              )

create_folders(img_paths=val_images, 
               annot_paths=val_annotations,
               img_dest="/kaggle/working/roadsigndetection/valid/images",
               annot_dest="/kaggle/working/roadsigndetection/valid/labels"
              )
# Out:
#   0%|          | 0/701 [00:00<?, ?it/s]
#   0%|          | 0/176 [00:00<?, ?it/s]

# %%
# os.listdir("/kaggle/working/roadsigndetection/train/labels")

# %%
class CFG:
    DEBUG = False
    FRACTION = 0.05 if DEBUG else 1.0
    SEED = 42

    # training
#     EPOCHS = 3 if DEBUG else 50 # 100
    EPOCHS = 15
    BATCH_SIZE = 8

    BASE_MODEL = 'yolov8n' # yolov8n, yolov8s, yolov8m, yolov8l, yolov8x, yolov9c, yolov9e
    BASE_MODEL_WEIGHTS = f'{BASE_MODEL}.pt'
    EXP_NAME = f'road_sign_{EPOCHS}_epochs'

    OPTIMIZER = 'auto' # SGD, Adam, Adamax, AdamW, NAdam, RAdam, RMSProp, auto
    LR = 1e-3
    LR_FACTOR = 0.01
    WEIGHT_DECAY = 5e-4
    DROPOUT = 0.0
    PATIENCE = 20
    PROFILE = False

    CUSTOM_DATASET_DIR = "/kaggle/working/roadsigndetection"
    OUTPUT_DIR = os.getcwd()
#     OUTPUT_DIR = "/kaggle/working/roadsigndetection/"

# %%
dict_file = {
    "train": os.path.join(CFG.CUSTOM_DATASET_DIR, "train"),
    "val": os.path.join(CFG.CUSTOM_DATASET_DIR, "valid"),
#     "test": os.path.join(CFG.CUSTOM_DATASET_DIR, "test"),
    "nc": 4,
    "names": {0: "trafficlight",
             1: "stop",
             2: "speedlimit",
             3: "crosswalk"},
}

with open(os.path.join(CFG.OUTPUT_DIR, "data.yaml"), "w+") as f:
    yaml.dump(dict_file, f)

# %%
# read yaml file created
def read_yaml_file(file_path=CFG.CUSTOM_DATASET_DIR):
    with open(file_path, "r") as f:
        try:
            data = yaml.safe_load(f)
            return data
        except yaml.YAMLError as e:
            print(f"Error reading YAML: {e}")
            return None

def print_yaml_data(data):
    formatted_yaml = yaml.dump(data, default_style=False)
    print(formatted_yaml)

file_path = os.path.join(CFG.OUTPUT_DIR, "data.yaml")
yaml_data = read_yaml_file(file_path)

if yaml_data:
    print_yaml_data(yaml_data)
# Out:
# names:
#   0: trafficlight
#   1: stop
#   2: speedlimit
#   3: crosswalk
# nc: 4
# train: /kaggle/working/roadsigndetection/train
# val: /kaggle/working/roadsigndetection/valid

# %%
# !ls /kaggle/working/
# Out:
# data.yaml  road_sign_data.zip  roadsigndetection

# %%
# !zip -r /kaggle/working/road_sign_data.zip /kaggle/working/*
# Out:
# updating: kaggle/working/data.yaml (deflated 35%)
# updating: kaggle/working/roadsigndetection/ (stored 0%)
# updating: kaggle/working/roadsigndetection/valid/ (stored 0%)
# updating: kaggle/working/roadsigndetection/valid/labels/ (stored 0%)
# updating: kaggle/working/roadsigndetection/valid/labels/road51.txt (deflated 26%)
# updating: kaggle/working/roadsigndetection/valid/labels/road91.txt (deflated 17%)
# updating: kaggle/working/roadsigndetection/valid/labels/road233.txt (deflated 54%)
# updating: kaggle/working/roadsigndetection/valid/labels/road16.txt (deflated 38%)
# updating: kaggle/working/roadsigndetection/valid/labels/road630.txt (deflated 34%)
# updating: kaggle/working/roadsigndetection/valid/labels/road292.txt (deflated 52%)
# updating: kaggle/working/roadsigndetection/valid/labels/road762.txt (deflated 35%)
# updating: kaggle/working/roadsigndetection/valid/labels/road659.txt (deflated 45%)
# updating: kaggle/working/roadsigndetection/valid/labels/road115.txt (deflated 49%)
# updating: kaggle/working/roadsigndetection/valid/labels/road54.txt (deflated 44%)
# updating: kaggle/working/roadsigndetection/valid/labels/road70.txt (deflated 12%)
# updating: kaggle/working/roadsigndetection/valid/labels/road169.txt (deflated 41%)
# updating: kaggle/working/roadsigndetection/valid/labels/road663.txt (deflated 36%)
# updating: kaggle/working/roadsigndetection/valid/labels/road186.txt (deflated 46%)
# updating: kaggle/working/roadsigndetection/valid/labels/road525.txt (deflated 46%)
# updating: kaggle/working/roadsigndetection/valid/labels/road731.txt (deflated 58%)
# updating: kaggle/working/roadsigndetection/valid/labels/road309.txt (deflated 58%)
# updating: kaggle/working/roadsigndetection/valid/labels/road712.txt (deflated 59%)
# updating: kaggle/working/roadsigndetection/valid/labels/road415.txt (deflated 45%)
# updating: kaggle/working/roadsigndetection/valid/labels/road777.txt (deflated 51%)
# updating: kaggle/working/roadsigndetection/valid/labels/road787.txt (deflated 36%)
# updating: kaggle/working/roadsigndetection/valid/labels/road567.txt (deflated 40%)
# updating: kaggle/working/roadsigndetection/valid/labels/road601.txt (deflated 47%)
# updating: kaggle/working/roadsigndetection/valid/labels/road593.txt (deflated 42%)
# updating: kaggle/working/roadsigndetection/valid/labels/road344.txt (deflated 34%)
# updating: kaggle/working/roadsigndetection/valid/labels/road378.txt (deflated 43%)
# updating: kaggle/working/roadsigndetection/valid/labels/road248.txt (deflated 50%)
# updating: kaggle/working/roadsigndetection/valid/labels/road198.txt (deflated 47%)
# updating: kaggle/working/roadsigndetection/valid/labels/road381.txt (deflated 52%)
# updating: kaggle/working/roadsigndetection/valid/labels/road688.txt (deflated 52%)
# updating: kaggle/working/roadsigndetection/valid/labels/road657.txt (deflated 51%)
# updating: kaggle/working/roadsigndetection/valid/labels/road749.txt (deflated 67%)
# updating: kaggle/working/roadsigndetection/valid/labels/road782.txt (deflated 47%)
# updating: kaggle/working/roadsigndetection/valid/labels/road583.txt (deflated 48%)
# updating: kaggle/working/roadsigndetection/valid/labels/road25.txt (deflated 43%)
# updating: kaggle/working/roadsigndetection/valid/labels/road74.txt (deflated 15%)
# updating: kaggle/working/roadsigndetection/valid/labels/road530.txt (deflated 51%)
# updating: kaggle/working/roadsigndetection/valid/labels/road473.txt (deflated 45%)
# updating: kaggle/working/roadsigndetection/valid/labels/road711.txt (deflated 54%)
# updating: kaggle/working/roadsigndetection/valid/labels/road405.txt (deflated 13%)
# updating: kaggle/working/roadsigndetection/valid/labels/road310.txt (deflated 43%)
# updating: kaggle/working/roadsigndetection/valid/labels/road119.txt (deflated 13%)
# updating: kaggle/working/roadsigndetection/valid/labels/road232.txt (deflated 39%)
# updating: kaggle/working/roadsigndetection/valid/labels/road506.txt (deflated 7%)
# updating: kaggle/working/roadsigndetection/valid/labels/road472.txt (deflated 46%)
# updating: kaggle/working/roadsigndetection/valid/labels/road682.txt (deflated 43%)
# updating: kaggle/working/roadsigndetection/valid/labels/road341.txt (deflated 42%)
# updating: kaggle/working/roadsigndetection/valid/labels/road518.txt (deflated 34%)
# updating: kaggle/working/roadsigndetection/valid/labels/road842.txt (deflated 49%)
# updating: kaggle/working/roadsigndetection/valid/labels/road735.txt (deflated 52%)
# updating: kaggle/working/roadsigndetection/valid/labels/road707.txt (deflated 51%)
# updating: kaggle/working/roadsigndetection/valid/labels/road327.txt (deflated 46%)
# updating: kaggle/working/roadsigndetection/valid/labels/road421.txt (deflated 45%)
# updating: kaggle/working/roadsigndetection/valid/labels/road436.txt (deflated 51%)
# updating: kaggle/working/roadsigndetection/valid/labels/road412.txt (deflated 52%)
# updating: kaggle/working/roadsigndetection/valid/labels/road231.txt (deflated 49%)
# updating: kaggle/working/roadsigndetection/valid/labels/road774.txt (deflated 17%)
# updating: kaggle/working/roadsigndetection/valid/labels/road806.txt (deflated 17%)
# updating: kaggle/working/roadsigndetection/valid/labels/road384.txt (deflated 36%)
# updating: kaggle/working/roadsigndetection/valid/labels/road354.txt (deflated 38%)
# updating: kaggle/working/roadsigndetection/valid/labels/road805.txt (deflated 37%)
# updating: kaggle/working/roadsigndetection/valid/labels/road55.txt (deflated 11%)
# updating: kaggle/working/roadsigndetection/valid/labels/road225.txt (deflated 54%)
# updating: kaggle/working/roadsigndetection/valid/labels/road534.txt (deflated 56%)
# updating: kaggle/working/roadsigndetection/valid/labels/road294.txt (deflated 42%)
# updating: kaggle/working/roadsigndetection/valid/labels/road205.txt (deflated 36%)
# updating: kaggle/working/roadsigndetection/valid/labels/road218.txt (deflated 37%)
# updating: kaggle/working/roadsigndetection/valid/labels/road468.txt (deflated 52%)
# updating: kaggle/working/roadsigndetection/valid/labels/road332.txt (deflated 18%)
# updating: kaggle/working/roadsigndetection/valid/labels/road550.txt (deflated 34%)
# updating: kaggle/working/roadsigndetection/valid/labels/road77.txt (deflated 14%)
# updating: kaggle/working/roadsigndetection/valid/labels/road470.txt (deflated 51%)
# updating: kaggle/working/roadsigndetection/valid/labels/road373.txt (deflated 33%)
# updating: kaggle/working/roadsigndetection/valid/labels/road427.txt (deflated 38%)
# updating: kaggle/working/roadsigndetection/valid/labels/road476.txt (deflated 37%)
# updating: kaggle/working/roadsigndetection/valid/labels/road486.txt (deflated 45%)
# updating: kaggle/working/roadsigndetection/valid/labels/road404.txt (deflated 45%)
# updating: kaggle/working/roadsigndetection/valid/labels/road738.txt (deflated 44%)
# updating: kaggle/working/roadsigndetection/valid/labels/road187.txt (deflated 32%)
# updating: kaggle/working/roadsigndetection/valid/labels/road185.txt (deflated 45%)
# updating: kaggle/working/roadsigndetection/valid/labels/road803.txt (deflated 41%)
# updating: kaggle/working/roadsigndetection/valid/labels/road379.txt (deflated 41%)
# updating: kaggle/working/roadsigndetection/valid/labels/road750.txt (deflated 51%)
# updating: kaggle/working/roadsigndetection/valid/labels/road23.txt (deflated 21%)
# updating: kaggle/working/roadsigndetection/valid/labels/road362.txt (deflated 35%)
# updating: kaggle/working/roadsigndetection/valid/labels/road617.txt (deflated 55%)
# updating: kaggle/working/roadsigndetection/valid/labels/road548.txt (deflated 35%)
# updating: kaggle/working/roadsigndetection/valid/labels/road626.txt (deflated 52%)
# updating: kaggle/working/roadsigndetection/valid/labels/road507.txt (deflated 15%)
# updating: kaggle/working/roadsigndetection/valid/labels/road748.txt (deflated 48%)
# updating: kaggle/working/roadsigndetection/valid/labels/road38.txt (deflated 35%)
# updating: kaggle/working/roadsigndetection/valid/labels/road216.txt (deflated 46%)
# updating: kaggle/working/roadsigndetection/valid/labels/road503.txt (deflated 42%)
# updating: kaggle/working/roadsigndetection/valid/labels/road687.txt (deflated 61%)
# updating: kaggle/working/roadsigndetection/valid/labels/road768.txt (deflated 49%)
# updating: kaggle/working/roadsigndetection/valid/labels/road516.txt (deflated 44%)
# updating: kaggle/working/roadsigndetection/valid/labels/road356.txt (deflated 32%)
# updating: kaggle/working/roadsigndetection/valid/labels/road732.txt (deflated 43%)
# updating: kaggle/working/roadsigndetection/valid/labels/road798.txt (deflated 29%)
# updating: kaggle/working/roadsigndetection/valid/labels/road713.txt (deflated 38%)
# updating: kaggle/working/roadsigndetection/valid/labels/road722.txt (deflated 31%)
# updating: kaggle/working/roadsigndetection/valid/labels/road288.txt (deflated 35%)
# updating: kaggle/working/roadsigndetection/valid/labels/road246.txt (deflated 35%)
# updating: kaggle/working/roadsigndetection/valid/labels/road865.txt (deflated 52%)
# updating: kaggle/working/roadsigndetection/valid/labels/road6.txt (deflated 14%)
# updating: kaggle/working/roadsigndetection/valid/labels/road595.txt (deflated 48%)
# updating: kaggle/working/roadsigndetection/valid/labels/road863.txt (deflated 45%)
# updating: kaggle/working/roadsigndetection/valid/labels/road72.txt (deflated 20%)
# updating: kaggle/working/roadsigndetection/valid/labels/road69.txt (deflated 12%)
# updating: kaggle/working/roadsigndetection/valid/labels/road807.txt (deflated 48%)
# updating: kaggle/working/roadsigndetection/valid/labels/road508.txt (deflated 63%)
# updating: kaggle/working/roadsigndetection/valid/labels/road190.txt (deflated 41%)
# updating: kaggle/working/roadsigndetection/valid/labels/road151.txt (deflated 11%)
# updating: kaggle/working/roadsigndetection/valid/labels/road59.txt (deflated 13%)
# updating: kaggle/working/roadsigndetection/valid/labels/road60.txt (deflated 44%)
# updating: kaggle/working/roadsigndetection/valid/labels/road141.txt (deflated 48%)
# updating: kaggle/working/roadsigndetection/valid/labels/road181.txt (deflated 46%)
# updating: kaggle/working/roadsigndetection/valid/labels/road744.txt (deflated 42%)
# updating: kaggle/working/roadsigndetection/valid/labels/road558.txt (deflated 36%)
# updating: kaggle/working/roadsigndetection/valid/labels/road724.txt (deflated 39%)
# updating: kaggle/working/roadsigndetection/valid/labels/road463.txt (deflated 45%)
# updating: kaggle/working/roadsigndetection/valid/labels/road479.txt (deflated 49%)
# updating: kaggle/working/roadsigndetection/valid/labels/road343.txt (deflated 38%)
# updating: kaggle/working/roadsigndetection/valid/labels/road31.txt (deflated 49%)
# updating: kaggle/working/roadsigndetection/valid/labels/road547.txt (deflated 55%)
# updating: kaggle/working/roadsigndetection/valid/labels/road820.txt (deflated 68%)
# updating: kaggle/working/roadsigndetection/valid/labels/road213.txt (deflated 43%)
# updating: kaggle/working/roadsigndetection/valid/labels/road597.txt (deflated 40%)
# updating: kaggle/working/roadsigndetection/valid/labels/road689.txt (deflated 48%)
# updating: kaggle/working/roadsigndetection/valid/labels/road694.txt (deflated 47%)
# updating: kaggle/working/roadsigndetection/valid/labels/road605.txt (deflated 44%)
# updating: kaggle/working/roadsigndetection/valid/labels/road487.txt (deflated 13%)
# updating: kaggle/working/roadsigndetection/valid/labels/road180.txt (deflated 49%)
# updating: kaggle/working/roadsigndetection/valid/labels/road30.txt (deflated 14%)
# updating: kaggle/working/roadsigndetection/valid/labels/road586.txt (deflated 47%)
# updating: kaggle/working/roadsigndetection/valid/labels/road430.txt (deflated 46%)
# updating: kaggle/working/roadsigndetection/valid/labels/road477.txt (deflated 46%)
# updating: kaggle/working/roadsigndetection/valid/labels/road353.txt (deflated 51%)
# updating: kaggle/working/roadsigndetection/valid/labels/road729.txt (deflated 67%)
# updating: kaggle/working/roadsigndetection/valid/labels/road400.txt (deflated 36%)
# updating: kaggle/working/roadsigndetection/valid/labels/road565.txt (deflated 46%)
# updating: kaggle/working/roadsigndetection/valid/labels/road103.txt (deflated 11%)
# updating: kaggle/working/roadsigndetection/valid/labels/road46.txt (deflated 12%)
# updating: kaggle/working/roadsigndetection/valid/labels/road71.txt (deflated 26%)
# updating: kaggle/working/roadsigndetection/valid/labels/road706.txt (deflated 46%)
# updating: kaggle/working/roadsigndetection/valid/labels/road675.txt (deflated 45%)
# updating: kaggle/working/roadsigndetection/valid/labels/road627.txt (deflated 47%)
# updating: kaggle/working/roadsigndetection/valid/labels/road791.txt (deflated 48%)
# updating: kaggle/working/roadsigndetection/valid/labels/road264.txt (deflated 43%)
# updating: kaggle/working/roadsigndetection/valid/labels/road352.txt (deflated 38%)
# updating: kaggle/working/roadsigndetection/valid/labels/road87.txt (deflated 13%)
# updating: kaggle/working/roadsigndetection/valid/labels/road2.txt (deflated 13%)
# updating: kaggle/working/roadsigndetection/valid/labels/road545.txt (deflated 49%)
# updating: kaggle/working/roadsigndetection/valid/labels/road253.txt (deflated 40%)
# updating: kaggle/working/roadsigndetection/valid/labels/road304.txt (deflated 51%)
# updating: kaggle/working/roadsigndetection/valid/labels/road650.txt (deflated 7%)
# updating: kaggle/working/roadsigndetection/valid/labels/road718.txt (deflated 54%)
# updating: kaggle/working/roadsigndetection/valid/labels/road563.txt (deflated 53%)
# updating: kaggle/working/roadsigndetection/valid/labels/road866.txt (deflated 40%)
# updating: kaggle/working/roadsigndetection/valid/labels/road202.txt (deflated 39%)
# updating: kaggle/working/roadsigndetection/valid/labels/road295.txt (deflated 18%)
# updating: kaggle/working/roadsigndetection/valid/labels/road134.txt (deflated 33%)
# updating: kaggle/working/roadsigndetection/valid/labels/road192.txt (deflated 32%)
# updating: kaggle/working/roadsigndetection/valid/labels/road817.txt (deflated 48%)
# updating: kaggle/working/roadsigndetection/valid/labels/road839.txt (deflated 48%)
# updating: kaggle/working/roadsigndetection/valid/labels/road788.txt (deflated 44%)
# updating: kaggle/working/roadsigndetection/valid/labels/road666.txt (deflated 46%)
# updating: kaggle/working/roadsigndetection/valid/labels/road220.txt (deflated 40%)
# updating: kaggle/working/roadsigndetection/valid/labels/road846.txt (deflated 53%)
# updating: kaggle/working/roadsigndetection/valid/labels/road517.txt (deflated 48%)
# updating: kaggle/working/roadsigndetection/valid/labels/road522.txt (deflated 48%)
# updating: kaggle/working/roadsigndetection/valid/labels/road411.txt (deflated 45%)
# updating: kaggle/working/roadsigndetection/valid/labels/road869.txt (deflated 58%)
# updating: kaggle/working/roadsigndetection/valid/labels/road484.txt (deflated 12%)
# updating: kaggle/working/roadsigndetection/valid/labels/road94.txt (deflated 15%)
# updating: kaggle/working/roadsigndetection/valid/labels/road283.txt (deflated 34%)
# updating: kaggle/working/roadsigndetection/valid/images/ (stored 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road605.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road506.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road547.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road354.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road735.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road25.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road180.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road218.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road30.png (deflated 1%)
# updating: kaggle/working/roadsigndetection/valid/images/road436.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road412.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road362.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road384.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road597.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road411.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road508.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road115.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road356.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road341.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road91.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road689.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road430.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road6.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road774.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road798.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road472.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road141.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road205.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road476.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road487.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road663.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road707.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road119.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road750.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road675.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road264.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road309.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road630.png (deflated 1%)
# updating: kaggle/working/roadsigndetection/valid/images/road525.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road806.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road231.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road186.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road415.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road310.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road583.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road507.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road253.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road842.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road468.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road202.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road586.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road817.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road713.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road295.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road213.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road378.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road749.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road187.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road292.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road94.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road807.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road181.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road711.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road134.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road548.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road627.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road400.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road687.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road192.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road846.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road69.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road650.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road70.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road232.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road712.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road788.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road294.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road59.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road405.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road31.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road233.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road87.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road768.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road379.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road332.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road530.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road762.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road23.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road55.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road103.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road863.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road522.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road2.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road169.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road463.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road787.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road353.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road722.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road748.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road601.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road791.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road682.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road738.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road198.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road565.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road54.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road803.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road688.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road190.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road344.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road724.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road343.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road373.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road550.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road486.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road820.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road484.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road248.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road304.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road626.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road246.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road839.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road470.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road216.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road865.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road545.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road185.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road516.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road74.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road473.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road805.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road479.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road659.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road288.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road352.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road706.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road404.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road427.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road694.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road225.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road744.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road71.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road38.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road46.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road503.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road77.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road657.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road567.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road593.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road60.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road283.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road421.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road381.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road558.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road729.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road518.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road595.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road732.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road51.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road563.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road151.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road731.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road777.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road782.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road517.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road869.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road718.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road327.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road534.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road666.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road72.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road617.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road16.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road477.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road866.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/valid/images/road220.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/ (stored 0%)
# updating: kaggle/working/roadsigndetection/train/labels/ (stored 0%)
# updating: kaggle/working/roadsigndetection/train/labels/road397.txt (deflated 43%)
# updating: kaggle/working/roadsigndetection/train/labels/road499.txt (deflated 44%)
# updating: kaggle/working/roadsigndetection/train/labels/road348.txt (deflated 37%)
# updating: kaggle/working/roadsigndetection/train/labels/road543.txt (deflated 54%)
# updating: kaggle/working/roadsigndetection/train/labels/road868.txt (deflated 32%)
# updating: kaggle/working/roadsigndetection/train/labels/road872.txt (deflated 41%)
# updating: kaggle/working/roadsigndetection/train/labels/road53.txt (deflated 26%)
# updating: kaggle/working/roadsigndetection/train/labels/road511.txt (deflated 45%)
# updating: kaggle/working/roadsigndetection/train/labels/road745.txt (deflated 58%)
# updating: kaggle/working/roadsigndetection/train/labels/road556.txt (deflated 37%)
# updating: kaggle/working/roadsigndetection/train/labels/road509.txt (deflated 47%)
# updating: kaggle/working/roadsigndetection/train/labels/road552.txt (deflated 34%)
# updating: kaggle/working/roadsigndetection/train/labels/road114.txt (deflated 16%)
# updating: kaggle/working/roadsigndetection/train/labels/road193.txt (deflated 39%)
# updating: kaggle/working/roadsigndetection/train/labels/road27.txt (deflated 34%)
# updating: kaggle/working/roadsigndetection/train/labels/road174.txt (deflated 46%)
# updating: kaggle/working/roadsigndetection/train/labels/road102.txt (deflated 10%)
# updating: kaggle/working/roadsigndetection/train/labels/road315.txt (deflated 51%)
# updating: kaggle/working/roadsigndetection/train/labels/road168.txt (deflated 31%)
# updating: kaggle/working/roadsigndetection/train/labels/road90.txt (deflated 12%)
# updating: kaggle/working/roadsigndetection/train/labels/road754.txt (deflated 50%)
# updating: kaggle/working/roadsigndetection/train/labels/road223.txt (deflated 51%)
# updating: kaggle/working/roadsigndetection/train/labels/road194.txt (deflated 43%)
# updating: kaggle/working/roadsigndetection/train/labels/road442.txt (deflated 40%)
# updating: kaggle/working/roadsigndetection/train/labels/road297.txt (deflated 45%)
# updating: kaggle/working/roadsigndetection/train/labels/road794.txt (deflated 45%)
# updating: kaggle/working/roadsigndetection/train/labels/road637.txt (deflated 36%)
# updating: kaggle/working/roadsigndetection/train/labels/road546.txt (deflated 58%)
# updating: kaggle/working/roadsigndetection/train/labels/road391.txt (deflated 49%)
# updating: kaggle/working/roadsigndetection/train/labels/road64.txt (deflated 13%)
# updating: kaggle/working/roadsigndetection/train/labels/road209.txt (deflated 48%)
# updating: kaggle/working/roadsigndetection/train/labels/road544.txt (deflated 52%)
# updating: kaggle/working/roadsigndetection/train/labels/road76.txt (deflated 16%)
# updating: kaggle/working/roadsigndetection/train/labels/road99.txt (deflated 14%)
# updating: kaggle/working/roadsigndetection/train/labels/road0.txt (deflated 15%)
# updating: kaggle/working/roadsigndetection/train/labels/road49.txt (deflated 34%)
# updating: kaggle/working/roadsigndetection/train/labels/road35.txt (deflated 13%)
# updating: kaggle/working/roadsigndetection/train/labels/road357.txt (deflated 51%)
# updating: kaggle/working/roadsigndetection/train/labels/road690.txt (deflated 47%)
# updating: kaggle/working/roadsigndetection/train/labels/road229.txt (deflated 61%)
# updating: kaggle/working/roadsigndetection/train/labels/road147.txt (deflated 11%)
# updating: kaggle/working/roadsigndetection/train/labels/road564.txt (deflated 47%)
# updating: kaggle/working/roadsigndetection/train/labels/road746.txt (deflated 44%)
# updating: kaggle/working/roadsigndetection/train/labels/road339.txt (deflated 36%)
# updating: kaggle/working/roadsigndetection/train/labels/road454.txt (deflated 37%)
# updating: kaggle/working/roadsigndetection/train/labels/road104.txt (deflated 31%)
# updating: kaggle/working/roadsigndetection/train/labels/road347.txt (deflated 44%)
# updating: kaggle/working/roadsigndetection/train/labels/road222.txt (deflated 46%)
# updating: kaggle/working/roadsigndetection/train/labels/road418.txt (deflated 51%)
# updating: kaggle/working/roadsigndetection/train/labels/road280.txt (deflated 47%)
# updating: kaggle/working/roadsigndetection/train/labels/road138.txt (deflated 36%)
# updating: kaggle/working/roadsigndetection/train/labels/road598.txt (deflated 42%)
# updating: kaggle/working/roadsigndetection/train/labels/road778.txt (deflated 43%)
# updating: kaggle/working/roadsigndetection/train/labels/road850.txt (deflated 47%)
# updating: kaggle/working/roadsigndetection/train/labels/road330.txt (deflated 51%)
# updating: kaggle/working/roadsigndetection/train/labels/road618.txt (deflated 41%)
# updating: kaggle/working/roadsigndetection/train/labels/road123.txt (deflated 13%)
# updating: kaggle/working/roadsigndetection/train/labels/road419.txt (deflated 40%)
# updating: kaggle/working/roadsigndetection/train/labels/road825.txt (deflated 65%)
# updating: kaggle/working/roadsigndetection/train/labels/road261.txt (deflated 46%)
# updating: kaggle/working/roadsigndetection/train/labels/road804.txt (deflated 46%)
# updating: kaggle/working/roadsigndetection/train/labels/road761.txt (deflated 42%)
# updating: kaggle/working/roadsigndetection/train/labels/road579.txt (deflated 49%)
# updating: kaggle/working/roadsigndetection/train/labels/road388.txt (deflated 52%)
# updating: kaggle/working/roadsigndetection/train/labels/road662.txt (deflated 36%)
# updating: kaggle/working/roadsigndetection/train/labels/road386.txt (deflated 45%)
# updating: kaggle/working/roadsigndetection/train/labels/road539.txt (deflated 38%)
# updating: kaggle/working/roadsigndetection/train/labels/road531.txt (deflated 60%)
# updating: kaggle/working/roadsigndetection/train/labels/road492.txt (deflated 34%)
# updating: kaggle/working/roadsigndetection/train/labels/road176.txt (deflated 42%)
# updating: kaggle/working/roadsigndetection/train/labels/road274.txt (deflated 44%)
# updating: kaggle/working/roadsigndetection/train/labels/road179.txt (deflated 64%)
# updating: kaggle/working/roadsigndetection/train/labels/road449.txt (deflated 7%)
# updating: kaggle/working/roadsigndetection/train/labels/road50.txt (deflated 12%)
# updating: kaggle/working/roadsigndetection/train/labels/road270.txt (deflated 51%)
# updating: kaggle/working/roadsigndetection/train/labels/road859.txt (deflated 48%)
# updating: kaggle/working/roadsigndetection/train/labels/road58.txt (deflated 27%)
# updating: kaggle/working/roadsigndetection/train/labels/road137.txt (deflated 14%)
# updating: kaggle/working/roadsigndetection/train/labels/road515.txt (deflated 12%)
# updating: kaggle/working/roadsigndetection/train/labels/road684.txt (deflated 51%)
# updating: kaggle/working/roadsigndetection/train/labels/road480.txt (deflated 51%)
# updating: kaggle/working/roadsigndetection/train/labels/road10.txt (deflated 13%)
# updating: kaggle/working/roadsigndetection/train/labels/road613.txt (deflated 52%)
# updating: kaggle/working/roadsigndetection/train/labels/road287.txt (deflated 52%)
# updating: kaggle/working/roadsigndetection/train/labels/road741.txt (deflated 51%)
# updating: kaggle/working/roadsigndetection/train/labels/road824.txt (deflated 61%)
# updating: kaggle/working/roadsigndetection/train/labels/road351.txt (deflated 50%)
# updating: kaggle/working/roadsigndetection/train/labels/road363.txt (deflated 38%)
# updating: kaggle/working/roadsigndetection/train/labels/road350.txt (deflated 46%)
# updating: kaggle/working/roadsigndetection/train/labels/road831.txt (deflated 59%)
# updating: kaggle/working/roadsigndetection/train/labels/road153.txt (deflated 15%)
# updating: kaggle/working/roadsigndetection/train/labels/road284.txt (deflated 23%)
# updating: kaggle/working/roadsigndetection/train/labels/road655.txt (deflated 51%)
# updating: kaggle/working/roadsigndetection/train/labels/road136.txt (deflated 35%)
# updating: kaggle/working/roadsigndetection/train/labels/road816.txt (deflated 36%)
# updating: kaggle/working/roadsigndetection/train/labels/road456.txt (deflated 29%)
# updating: kaggle/working/roadsigndetection/train/labels/road355.txt (deflated 36%)
# updating: kaggle/working/roadsigndetection/train/labels/road843.txt (deflated 34%)
# updating: kaggle/working/roadsigndetection/train/labels/road219.txt (deflated 41%)
# updating: kaggle/working/roadsigndetection/train/labels/road92.txt (deflated 13%)
# updating: kaggle/working/roadsigndetection/train/labels/road661.txt (deflated 46%)
# updating: kaggle/working/roadsigndetection/train/labels/road808.txt (deflated 49%)
# updating: kaggle/working/roadsigndetection/train/labels/road117.txt (deflated 41%)
# updating: kaggle/working/roadsigndetection/train/labels/road773.txt (deflated 50%)
# updating: kaggle/working/roadsigndetection/train/labels/road665.txt (deflated 40%)
# updating: kaggle/working/roadsigndetection/train/labels/road823.txt (deflated 57%)
# updating: kaggle/working/roadsigndetection/train/labels/road322.txt (deflated 49%)
# updating: kaggle/working/roadsigndetection/train/labels/road369.txt (deflated 40%)
# updating: kaggle/working/roadsigndetection/train/labels/road653.txt (deflated 52%)
# updating: kaggle/working/roadsigndetection/train/labels/road577.txt (deflated 27%)
# updating: kaggle/working/roadsigndetection/train/labels/road438.txt (deflated 46%)
# updating: kaggle/working/roadsigndetection/train/labels/road207.txt (deflated 30%)
# updating: kaggle/working/roadsigndetection/train/labels/road728.txt (deflated 53%)
# updating: kaggle/working/roadsigndetection/train/labels/road488.txt (deflated 33%)
# updating: kaggle/working/roadsigndetection/train/labels/road230.txt (deflated 70%)
# updating: kaggle/working/roadsigndetection/train/labels/road393.txt (deflated 8%)
# updating: kaggle/working/roadsigndetection/train/labels/road319.txt (deflated 57%)
# updating: kaggle/working/roadsigndetection/train/labels/road21.txt (deflated 62%)
# updating: kaggle/working/roadsigndetection/train/labels/road590.txt (deflated 41%)
# updating: kaggle/working/roadsigndetection/train/labels/road553.txt (deflated 39%)
# updating: kaggle/working/roadsigndetection/train/labels/road289.txt (deflated 44%)
# updating: kaggle/working/roadsigndetection/train/labels/road48.txt (deflated 36%)
# updating: kaggle/working/roadsigndetection/train/labels/road709.txt (deflated 55%)
# updating: kaggle/working/roadsigndetection/train/labels/road435.txt (deflated 13%)
# updating: kaggle/working/roadsigndetection/train/labels/road622.txt (deflated 36%)
# updating: kaggle/working/roadsigndetection/train/labels/road498.txt (deflated 40%)
# updating: kaggle/working/roadsigndetection/train/labels/road66.txt (deflated 12%)
# updating: kaggle/working/roadsigndetection/train/labels/road500.txt (deflated 19%)
# updating: kaggle/working/roadsigndetection/train/labels/road683.txt (deflated 38%)
# updating: kaggle/working/roadsigndetection/train/labels/road828.txt (deflated 42%)
# updating: kaggle/working/roadsigndetection/train/labels/road228.txt (deflated 51%)
# updating: kaggle/working/roadsigndetection/train/labels/road342.txt (deflated 44%)
# updating: kaggle/working/roadsigndetection/train/labels/road428.txt (deflated 54%)
# updating: kaggle/working/roadsigndetection/train/labels/road697.txt (deflated 38%)
# updating: kaggle/working/roadsigndetection/train/labels/road692.txt (deflated 46%)
# updating: kaggle/working/roadsigndetection/train/labels/road331.txt (deflated 58%)
# updating: kaggle/working/roadsigndetection/train/labels/road3.txt (deflated 44%)
# updating: kaggle/working/roadsigndetection/train/labels/road112.txt (deflated 13%)
# updating: kaggle/working/roadsigndetection/train/labels/road89.txt (deflated 13%)
# updating: kaggle/working/roadsigndetection/train/labels/road432.txt (deflated 46%)
# updating: kaggle/working/roadsigndetection/train/labels/road623.txt (deflated 38%)
# updating: kaggle/working/roadsigndetection/train/labels/road708.txt (deflated 59%)
# updating: kaggle/working/roadsigndetection/train/labels/road305.txt (deflated 38%)
# updating: kaggle/working/roadsigndetection/train/labels/road490.txt (deflated 51%)
# updating: kaggle/working/roadsigndetection/train/labels/road431.txt (deflated 47%)
# updating: kaggle/working/roadsigndetection/train/labels/road81.txt (deflated 38%)
# updating: kaggle/working/roadsigndetection/train/labels/road624.txt (deflated 51%)
# updating: kaggle/working/roadsigndetection/train/labels/road167.txt (deflated 54%)
# updating: kaggle/working/roadsigndetection/train/labels/road554.txt (deflated 52%)
# updating: kaggle/working/roadsigndetection/train/labels/road157.txt (deflated 11%)
# updating: kaggle/working/roadsigndetection/train/labels/road747.txt (deflated 51%)
# updating: kaggle/working/roadsigndetection/train/labels/road734.txt (deflated 53%)
# updating: kaggle/working/roadsigndetection/train/labels/road851.txt (deflated 29%)
# updating: kaggle/working/roadsigndetection/train/labels/road39.txt (deflated 25%)
# updating: kaggle/working/roadsigndetection/train/labels/road173.txt (deflated 36%)
# updating: kaggle/working/roadsigndetection/train/labels/road771.txt (deflated 37%)
# updating: kaggle/working/roadsigndetection/train/labels/road255.txt (deflated 47%)
# updating: kaggle/working/roadsigndetection/train/labels/road572.txt (deflated 52%)
# updating: kaggle/working/roadsigndetection/train/labels/road702.txt (deflated 53%)
# updating: kaggle/working/roadsigndetection/train/labels/road867.txt (deflated 37%)
# updating: kaggle/working/roadsigndetection/train/labels/road533.txt (deflated 62%)
# updating: kaggle/working/roadsigndetection/train/labels/road573.txt (deflated 63%)
# updating: kaggle/working/roadsigndetection/train/labels/road160.txt (deflated 58%)
# updating: kaggle/working/roadsigndetection/train/labels/road95.txt (deflated 46%)
# updating: kaggle/working/roadsigndetection/train/labels/road591.txt (deflated 51%)
# updating: kaggle/working/roadsigndetection/train/labels/road540.txt (deflated 47%)
# updating: kaggle/working/roadsigndetection/train/labels/road698.txt (deflated 48%)
# updating: kaggle/working/roadsigndetection/train/labels/road569.txt (deflated 39%)
# updating: kaggle/working/roadsigndetection/train/labels/road398.txt (deflated 18%)
# updating: kaggle/working/roadsigndetection/train/labels/road582.txt (deflated 59%)
# updating: kaggle/working/roadsigndetection/train/labels/road156.txt (deflated 35%)
# updating: kaggle/working/roadsigndetection/train/labels/road633.txt (deflated 38%)
# updating: kaggle/working/roadsigndetection/train/labels/road727.txt (deflated 56%)
# updating: kaggle/working/roadsigndetection/train/labels/road320.txt (deflated 45%)
# updating: kaggle/working/roadsigndetection/train/labels/road407.txt (deflated 37%)
# updating: kaggle/working/roadsigndetection/train/labels/road797.txt (deflated 46%)
# updating: kaggle/working/roadsigndetection/train/labels/road267.txt (deflated 48%)
# updating: kaggle/working/roadsigndetection/train/labels/road764.txt (deflated 50%)
# updating: kaggle/working/roadsigndetection/train/labels/road227.txt (deflated 43%)
# updating: kaggle/working/roadsigndetection/train/labels/road864.txt (deflated 49%)
# updating: kaggle/working/roadsigndetection/train/labels/road144.txt (deflated 15%)
# updating: kaggle/working/roadsigndetection/train/labels/road22.txt (deflated 42%)
# updating: kaggle/working/roadsigndetection/train/labels/road120.txt (deflated 14%)
# updating: kaggle/working/roadsigndetection/train/labels/road406.txt (deflated 45%)
# updating: kaggle/working/roadsigndetection/train/labels/road107.txt (deflated 25%)
# updating: kaggle/working/roadsigndetection/train/labels/road83.txt (deflated 14%)
# updating: kaggle/working/roadsigndetection/train/labels/road376.txt (deflated 46%)
# updating: kaggle/working/roadsigndetection/train/labels/road122.txt (deflated 15%)
# updating: kaggle/working/roadsigndetection/train/labels/road242.txt (deflated 58%)
# updating: kaggle/working/roadsigndetection/train/labels/road390.txt (deflated 39%)
# updating: kaggle/working/roadsigndetection/train/labels/road767.txt (deflated 36%)
# updating: kaggle/working/roadsigndetection/train/labels/road557.txt (deflated 38%)
# updating: kaggle/working/roadsigndetection/train/labels/road279.txt (deflated 38%)
# updating: kaggle/working/roadsigndetection/train/labels/road609.txt (deflated 48%)
# updating: kaggle/working/roadsigndetection/train/labels/road307.txt (deflated 51%)
# updating: kaggle/working/roadsigndetection/train/labels/road28.txt (deflated 44%)
# updating: kaggle/working/roadsigndetection/train/labels/road42.txt (deflated 35%)
# updating: kaggle/working/roadsigndetection/train/labels/road620.txt (deflated 17%)
# updating: kaggle/working/roadsigndetection/train/labels/road809.txt (deflated 37%)
# updating: kaggle/working/roadsigndetection/train/labels/road382.txt (deflated 45%)
# updating: kaggle/working/roadsigndetection/train/labels/road159.txt (deflated 33%)
# updating: kaggle/working/roadsigndetection/train/labels/road447.txt (deflated 47%)
# updating: kaggle/working/roadsigndetection/train/labels/road680.txt (deflated 45%)
# updating: kaggle/working/roadsigndetection/train/labels/road587.txt (deflated 48%)
# updating: kaggle/working/roadsigndetection/train/labels/road639.txt (deflated 42%)
# updating: kaggle/working/roadsigndetection/train/labels/road606.txt (deflated 41%)
# updating: kaggle/working/roadsigndetection/train/labels/road714.txt (deflated 40%)
# updating: kaggle/working/roadsigndetection/train/labels/road847.txt (deflated 41%)
# updating: kaggle/working/roadsigndetection/train/labels/road720.txt (deflated 50%)
# updating: kaggle/working/roadsigndetection/train/labels/road221.txt (deflated 42%)
# updating: kaggle/working/roadsigndetection/train/labels/road370.txt (deflated 44%)
# updating: kaggle/working/roadsigndetection/train/labels/road299.txt (deflated 40%)
# updating: kaggle/working/roadsigndetection/train/labels/road757.txt (deflated 49%)
# updating: kaggle/working/roadsigndetection/train/labels/road401.txt (deflated 38%)
# updating: kaggle/working/roadsigndetection/train/labels/road224.txt (deflated 47%)
# updating: kaggle/working/roadsigndetection/train/labels/road15.txt (deflated 14%)
# updating: kaggle/working/roadsigndetection/train/labels/road441.txt (deflated 8%)
# updating: kaggle/working/roadsigndetection/train/labels/road392.txt (deflated 49%)
# updating: kaggle/working/roadsigndetection/train/labels/road281.txt (deflated 53%)
# updating: kaggle/working/roadsigndetection/train/labels/road365.txt (deflated 50%)
# updating: kaggle/working/roadsigndetection/train/labels/road837.txt (deflated 48%)
# updating: kaggle/working/roadsigndetection/train/labels/road795.txt (deflated 38%)
# updating: kaggle/working/roadsigndetection/train/labels/road217.txt (deflated 47%)
# updating: kaggle/working/roadsigndetection/train/labels/road505.txt (deflated 33%)
# ...
# updating: kaggle/working/roadsigndetection/train/images/road369.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road875.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road856.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road274.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road490.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road543.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road302.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road585.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road838.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road717.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road582.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road540.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road221.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road730.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road162.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road652.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road715.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road610.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road157.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road502.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road671.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road358.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road556.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road254.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road311.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road121.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road475.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road419.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road703.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road197.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road669.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road385.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road26.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road14.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road535.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road857.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road376.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road505.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road154.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road250.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road7.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road44.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road150.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road519.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road153.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road238.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road165.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road370.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road138.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road237.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road622.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road438.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road37.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road541.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road166.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road784.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road361.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road325.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road454.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road841.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road683.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road300.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road159.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road174.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road208.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road661.png (deflated 1%)
# updating: kaggle/working/roadsigndetection/train/images/road764.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road36.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road501.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road742.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road277.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road85.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road123.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road417.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road649.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road664.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road864.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road792.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road804.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road306.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road566.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road779.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road389.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road257.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road504.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road163.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road756.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road520.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road481.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road873.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road345.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road387.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road318.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road639.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road335.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road532.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road542.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road357.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road761.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road529.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road633.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road133.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road407.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road584.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road269.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road822.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road847.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road447.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road561.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road210.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road276.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road696.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road433.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road637.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road778.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road12.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road137.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road437.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road67.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road63.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road11.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road40.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road289.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road428.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road613.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road509.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road319.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road612.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road116.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road836.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road183.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road466.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road677.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road874.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road686.png (deflated 1%)
# updating: kaggle/working/roadsigndetection/train/images/road480.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road861.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road275.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road538.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road207.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road716.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road775.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road184.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road638.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road815.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road342.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road129.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road578.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road214.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road589.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road65.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road402.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road330.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road298.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road642.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road552.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road68.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road629.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road628.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road360.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road242.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road365.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road800.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road130.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road104.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road636.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road672.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road188.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road821.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road49.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road647.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road364.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road1.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road112.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road161.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road478.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road510.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road758.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road631.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road474.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road75.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road743.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road47.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road106.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road483.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road78.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road383.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road603.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road17.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road588.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road377.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road790.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road92.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road833.png (deflated 0%)
# updating: kaggle/working/roadsigndetection/train/images/road723.png (deflated 0%)
